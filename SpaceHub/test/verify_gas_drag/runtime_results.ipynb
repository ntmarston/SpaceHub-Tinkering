# %%
import sys, os, glob
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns

HERE = Path(os.path.abspath(""))
ROOT = HERE.parent.parent.parent if HERE.name == "verify_gas_drag" else HERE
sys.path.insert(0, str(ROOT))

from spacehub_calc import load_spacehub_data_live, TwoBodyOrbit
import util

# %%
OUT_DIR = HERE / "out" / "RuntimeDemo"

dat_files = sorted(p.name for p in OUT_DIR.glob("*.dat"))
log_files = sorted(p.name for p in OUT_DIR.glob("*.log"))

print(f"{len(dat_files)} .dat files, {len(log_files)} .log files")
