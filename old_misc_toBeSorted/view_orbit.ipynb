# %%
import spacehub_calc as sc
import spacehub_calc_notoptimized as scno
import spacehub_calc_notvectorized as scnv
import seaborn as sns 
from matplotlib import pyplot as plt 
import numpy as np 
import pandas as pd

# %%
filepath = "test/nick_test/KeplerSimple.dat"

# %%
import time

#Time optimized version
t0 = time.perf_counter()
#orb = scnv.TwoBodyOrbit(filepath, i=0, j=1)
t_opt = time.perf_counter() - t0

# Time non-optimized version
t0 = time.perf_counter()
orbno = scno.TwoBodyOrbit(filepath, i=0, j=1)
t_noopt = time.perf_counter() - t0

print(f"\n{'='*40}")
#print(f"Optimized:     {t_opt:.4f} s")
print(f"Non-optimized: {t_noopt:.4f} s")
#print(f"Speedup:       {t_noopt/t_opt:.2f}x")
# Out:
# load data complete
# Determining timesteps...
# Calculating orbital state vectors...
# Calculating scalar orbital elements...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 10
#       8 # Time non-optimized version
#       9 t0 = time.perf_counter()
# ---> 10 orbno = scno.TwoBodyOrbit(filepath, i=0, j=1)
#      11 t_noopt = time.perf_counter() - t0
#      13 print(f"\n{'='*40}")
#
# File ~/Computing/AGN/SpaceHub-Tinkering/spacehub_calc_notoptimized.py:556, in TwoBodyOrbit.__init__(self, filename, i, j)
#     554 self.set_ecc_vector()
#     555 print("Calculating scalar orbital elements...")
# --> 556 self.set_sma()
#     557 self.set_scalar_e()
#     558 self.set_inclination()
#
# File ~/Computing/AGN/SpaceHub-Tinkering/spacehub_calc_notoptimized.py:235, in TwoBodyOrbit.set_sma(self)
#     233 mi = get_tot_mass(data, i)
#     234 mj = get_tot_mass(data, j)
# ...

# %%
fig, axs = orb.plot_keplerian_evolution(plots=['e', 'a', 'i', 'R'], xlim=(0, 1000), figsize=(10,7))

# %%
fig, axs = orb.plot_keplerian_evolution(plots=['e', 'a', 'i', 'R'], xlim=(0, 1000), figsize=(10,7))

# %%
diffs = []
for new, old in zip(orb.c0, orbno.c0):
    diffs.append(new-old)

# %%
max(diffs)
